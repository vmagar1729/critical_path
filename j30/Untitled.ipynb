# %%
import os

path = "/Users/vivekmagar/Documents/GitHub/critical_path/test_data/j30/j301_1.sm"

print("Absolute path:", os.path.abspath(path))
print("Exists:", os.path.exists(path))

# print 20 lines of context around the duration block
with open(path, "r") as f:
    for i, line in enumerate(f):
        print(i, repr(line))
        if i > 70:
            break
# Out:
# Absolute path: /Users/vivekmagar/Documents/GitHub/critical_path/test_data/j30/j301_1.sm
# Exists: True
# 0 '************************************************************************\n'
# 1 'file with basedata            : j30_17.bas\n'
# 2 'initial value random generator: 28123\n'
# 3 '************************************************************************\n'
# 4 'projects                      :  1\n'
# 5 'jobs (incl. supersource/sink ):  32\n'
# 6 'horizon                       :  158\n'
# 7 'RESOURCES\n'
# 8 '  - renewable                 :  4   R\n'
# 9 '  - nonrenewable              :  0   N\n'
# 10 '  - doubly constrained        :  0   D\n'
# 11 '************************************************************************\n'
# 12 'PROJECT INFORMATION:\n'
# 13 'pronr.  #jobs rel.date duedate tardcost  MPM-Time\n'
# 14 '    1     30      0       38       26       38\n'
# 15 '************************************************************************\n'
# 16 'PRECEDENCE RELATIONS:\n'
# ...
