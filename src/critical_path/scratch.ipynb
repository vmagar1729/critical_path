# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/synthetic_schedules/schedule1.csv",
    parse_dates=["Start", "Finish", "Baseline Start", "Baseline Finish"]
)

# %%
from cpm.dual_cpm_csv import compute_dual_cpm_from_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from cpm.dual_cpm_csv import compute_dual_cpm_from_df
#
# ModuleNotFoundError: No module named 'cpm'
